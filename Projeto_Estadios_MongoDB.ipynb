# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfAndersonVanin/FATEC_Banco_de_Dados_NoSQL/blob/main/Projeto_Estadios_MongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importação das Bibliotecas

# %%
import numpy as np
import pandas as pd
import json

# %%
# Baixando o data set em csv
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_Banco_de_Dados_NoSQL/main/material%20de%20apoio/base%20de%20dados/Coordenadas%20csv.csv"

# %%
# Convertendo um arquivo csv em um Data Frame Pandas
estadios_df = pd.read_csv(dataset)

# %%
# Visualizando os 5 primeiros registros do DataFrame
estadios_df.head(15)
# Out:
#                  nome  capacidade  latitude  longitude
# 0            Maracanã       78838 -22.90981  -43.23391
# 1      Mané Garrincha       72000 -15.78375  -47.89903
# 2             Morumbi       66795 -23.60006  -46.72016
# 3      Arena Castelão       63903  -3.80674  -38.52168
# 4            Mineirão       61927 -19.86591  -43.97104
# 5              Arruda       60000  -8.02681  -34.89120
# 6     Arena do Grêmio       55662 -29.97404  -51.19511
# 7          Mangueirão       55645  -1.38114  -48.44483
# 8           Beira-Rio       50848 -30.06549  -51.23492
# 9   Neo Química Arena       48234 -23.54529  -46.47429
# 10   Arena Fonte Nova       48000 -12.97889  -38.50348
# 11    Parque do Sabiá       46782 -18.91309  -48.23299
# 12   Arena Pernambuco       46000  -8.02681  -34.89120
# 13          Arena MRV       46000 -19.93001  -44.01388
# 14          Prudentão       45954 -22.09857  -51.41506

# %%
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %% [markdown]
# Agora que temos nosso dicionário pronto, precisamos ter o ambiente MongoDB Atlas preparado para receber este dicionário que será uma nova colection em uma base de dados.

# %% [markdown]
# # Instalando as bibliotecas necessárias para o MongoDB

# %%
# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymongo
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 16.9 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 24.9 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.3.3

# %% [markdown]
# ## Conectando ao MongoAtlas

# %%
# estabelecendo uma variável que será o cliente de conexão ao Server Mongo
cliente = MongoClient("mongodb+srv://profandersonvanin:1234@cluster0.uzeqblm.mongodb.net/?retryWrites=true&w=majority")

# %%
# cliente = MongoClient("mongodb+srv://profandersonvanin:<password>@cluster0.uzeqblm.mongodb.net/?retryWrites=true&w=majority")

# %%
# Selecionando a base de dados
db = cliente.get_database('futebol')

# %%
# Insere os documentos na nova base de dados
db.estadios.insert_many(dicionario)

# %% [markdown]
# ## Importando a biblioteca Folium que serve para visualização de mapas

# %%
import folium

# %%
# recuperando uma collection em uma variavel
estadios = db.estadios

# %%
# Exibindo a quantidade de documentos em uma collection e exibindo o primeiro documento
num_documentos = estadios.count_documents({'_id' : {'$exists' : 1}})
print ( 'Número de documentos no Banco de Dados = ' + str(num_documentos) )
print("Mostando o primeiro documento")
list ( estadios.find().limit(1) )
# Out:
# Número de documentos no Banco de Dados = 20
# Mostando o primeiro documento
# [{'_id': ObjectId('645d77b90acb154ce9dd5102'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391}]

# %%
# Estabelecendo um ponto central do mapa (Centro do Brasil)
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
consulta
# Out:
# [{'_id': ObjectId('645d77b90acb154ce9dd5102'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('645d77b90acb154ce9dd5103'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('645d77b90acb154ce9dd5104'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('645d77b90acb154ce9dd5105'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('645d77b90acb154ce9dd5106'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('645d77b90acb154ce9dd5107'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('645d77b90acb154ce9dd5108'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('645d77b90acb154ce9dd5109'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('645d77b90acb154ce9dd510a'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('645d77b90acb154ce9dd510b'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('645d77b90acb154ce9dd510c'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('645d77b90acb154ce9dd510d'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('645d77b90acb154ce9dd510e'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('645d77b90acb154ce9dd510f'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('645d77b90acb154ce9dd5110'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('645d77b90acb154ce9dd5111'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('645d77b90acb154ce9dd5112'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('645d77b90acb154ce9dd5113'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('645d77b90acb154ce9dd5114'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('645d77b90acb154ce9dd5115'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
df_convertido = pd.DataFrame(consulta)

# %%
# Imprime a primeira linha do DataFrame
df_convertido.iloc[0]
# Out:
# _id           645d77b90acb154ce9dd5102
# nome                          Maracanã
# capacidade                       78838
# latitude                     -22.90981
# longitude                    -43.23391
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[ center_lat , center_lon ], zoom_start=5, width=800, height=600 )
longitud  = len(df_convertido)

# %%
for i in range ( longitud ):
    lng = float(df_convertido.iloc[i]['longitude'])
    lat = float(df_convertido.iloc[i]['latitude'])
    description = 'Estádio: ' + str(df_convertido.iloc[i]['nome'])+ '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
    folium.Marker( [ lat , lng ],
                 popup= description,
                 icon=folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c90ee71e475600fc72a4715fc623ed3c {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c90ee71e475600fc72a4715fc623ed3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c90ee71e475600fc72a4715fc623ed3c = L.map(
#                 &quot;map_c90ee71e475600fc72a4715fc623ed3c&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7b1b1b4dda2542b05a859ff12506489 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c90ee71e475600fc72a4715fc623ed3c);
#
#
#             var marker_cf25937bb567ca38c3898b28e8741b7b = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_c90ee71e475600fc72a4715fc623ed3c);
#
#
#             var icon_ae06e1828eec5f17bc4f27c9e9202a87 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cf25937bb567ca38c3898b28e8741b7b.setIcon(icon_ae06e1828eec5f17bc4f27c9e9202a87);
#
#
#         var popup_4bdd673c819215dab96b7cca12a2d632 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2483e12a30c57df0d387f8d7c10cc611 = $(`&lt;div id=&quot;html_2483e12a30c57df0d387f8d7c10cc611&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_4bdd673c819215dab96b7cca12a2d632.setContent(html_2483e12a30c57df0d387f8d7c10cc611);
#
#
#
#         marker_cf25937bb567ca38c3898b28e8741b7b.bindPopup(popup_4bdd673c819215dab96b7cca12a2d632)
#         ;
#
#
#
#
#             var marker_9779a8cd946ec9e66b82ab50df5a06b2 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_c90ee71e475600fc72a4715fc623ed3c);
#
#
#             var icon_5a160e5a62a6f1fd991fb56476899c76 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9779a8cd946ec9e66b82ab50df5a06b2.setIcon(icon_5a160e5a62a6f1fd991fb56476899c76);
#
#
#         var popup_42aa1c1c3970f731e4b8bff4dac554fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea8c5be7973137f85362434ddadb0493 = $(`&lt;div id=&quot;html_ea8c5be7973137f85362434ddadb0493&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_42aa1c1c3970f731e4b8bff4dac554fd.setContent(html_ea8c5be7973137f85362434ddadb0493);
#
#
#
#         marker_9779a8cd946ec9e66b82ab50df5a06b2.bindPopup(popup_42aa1c1c3970f731e4b8bff4dac554fd)
#         ;
#
#
#
#
#             var marker_d15e50ef65b4c47378de39a03d7efbc8 = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_c90ee71e475600fc72a4715fc623ed3c);
#
#
#             var icon_18c43825b649397514cce0ebb793f7fd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d15e50ef65b4c47378de39a03d7efbc8.setIcon(icon_18c43825b649397514cce0ebb793f7fd);
#
#
#         var popup_a9f5e10691a87cd9f75e7cad1bec1936 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bda45d6882c5f38afa6c4627c1c30918 = $(`&lt;div id=&quot;html_bda45d6882c5f38afa6c4627c1c30918&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Morumbi&lt;br&gt; Capacidade: 66795&lt;/div&gt;`)[0];
#                 popup_a9f5e10691a87cd9f75e7cad1bec1936.setContent(html_bda45d6882c5f38afa6c4627c1c30918);
#
#
#
#         marker_d15e50ef65b4c47378de39a03d7efbc8.bindPopup(popup_a9f5e10691a87cd9f75e7cad1bec1936)
#         ;
#
#
#
#
#             var marker_1bcf1dc03b86788bbd290759331a2710 = L.marker(
#                 [-3.80674, -38.52168],
#                 {}
#             ).addTo(map_c90ee71e475600fc72a4715fc623ed3c);
#
#
#             var icon_78577e1891d021f9bbe32a1c77f7d08f = L.AwesomeMarkers.ico

# %% [markdown]
# https://colab.research.google.com/github/Giffy/MongoDB_PyMongo_Tutorial/blob/master/1_1_First_steps_with_MongoDB_PyMongo.ipynb#scrollTo=fpS_a7o_FCVj

# %%
from pandas._config import reset_option
#@title PesquisaEstadio

#@markdown Pesquise detalhes de um estádio

Nome_estadio = "Neo Qu\xEDmica Arena" #@param ["Maracanã","Mané Garrincha","Morumbi","Arena Castelão","Mineirão","Arruda","Arena do Grêmio","Mangueirão","Beira-Rio","Neo Química Arena","Arena Fonte Nova","Parque do Sabiá","Arena Pernambuco","Arena MRV","Prudentão","Engenhão","Albertão","Morenão","Arena Pantanal","Arena da Amazônia"]

nome_estadio = {'nome' : Nome_estadio}
resultado_busca = list(estadios.find(nome_estadio))
print('Dados do Estádio: ',resultado_busca[0]['nome'])
print('Capacidade do estádio selecionado: ',resultado_busca[0]['capacidade'], ' pessoas')
print('Posição Geográfica')
print('Latitude: ',resultado_busca[0]['latitude'])
print('Longitude: ',resultado_busca[0]['longitude'])
   
lng = float(resultado_busca[0]['longitude'])
lat = float(resultado_busca[0]['latitude'])
description = 'AQUI'
locationmap2 = folium.Map(location=[ center_lat , center_lon ], zoom_start=4, width=800, height=600 )
folium.Marker( [ lat , lng ],popup= description,icon=folium.Icon(color='red')).add_to(locationmap2)
locationmap2
# Out:
# Dados do Estádio:  Neo Química Arena
# Capacidade do estádio selecionado:  48234  pessoas
# Posição Geográfica
# Latitude:  -23.54529
# Longitude:  -46.47429
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a127d50d30d2427dc3eac174a14af69 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a127d50d30d2427dc3eac174a14af69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a127d50d30d2427dc3eac174a14af69 = L.map(
#                 &quot;map_9a127d50d30d2427dc3eac174a14af69&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4656f11a829e06dbbc0d47831b6d534d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a127d50d30d2427dc3eac174a14af69);
#
#
#             var marker_f115603aee6b48031d4703bb06a5919c = L.marker(
#                 [-23.54529, -46.47429],
#                 {}
#             ).addTo(map_9a127d50d30d2427dc3eac174a14af69);
#
#
#             var icon_e4e3ccb076fb437f3f217fffaf7a488e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f115603aee6b48031d4703bb06a5919c.setIcon(icon_e4e3ccb076fb437f3f217fffaf7a488e);
#
#
#         var popup_cb6f0c646a9d0d3c0a92c1eef3e65ba2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_247144ee46407cda7aea707a02b18177 = $(`&lt;div id=&quot;html_247144ee46407cda7aea707a02b18177&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AQUI&lt;/div&gt;`)[0];
#                 popup_cb6f0c646a9d0d3c0a92c1eef3e65ba2.setContent(html_247144ee46407cda7aea707a02b18177);
#
#
#
#         marker_f115603aee6b48031d4703bb06a5919c.bindPopup(popup_cb6f0c646a9d0d3c0a92c1eef3e65ba2)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# nome_estadio = {'nome' : Nome_estadio}

# %%
# print(nome_estadio)

# %%
# resultado_busca = list(estadios.find(nome_estadio))
# print(resultado_busca)

# %%
# print('Dados do Estádio: ',resultado_busca[0]['nome'])
# print('Capacidade do estádio selecionado: ',resultado_busca[0]['capacidade'], ' pessoas')
# print('Posição Geográfica')
# print('Latitude: ',resultado_busca[0]['latitude'])
# print('Longitude: ',resultado_busca[0]['longitude'])
